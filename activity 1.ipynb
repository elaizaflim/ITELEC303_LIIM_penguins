# %% [markdown]
# <h1>Activity 1 - PALMER PENGUINS DATA ANALYTICS PROJECT </h1>
# <hr>
# <h3> Analyst : Elaiza Flores Lim </h3>

# %%
#import Libraries
import numpy as np
import pandas as pd

# %%
penguins = pd.read_csv('datasets\\penguins.csv')

# %%
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen            39.1           18.7              181.0
# 1       Adelie  Torgersen            39.5           17.4              186.0
# 2       Adelie  Torgersen            40.3           18.0              195.0
# 3       Adelie  Torgersen             NaN            NaN                NaN
# 4       Adelie  Torgersen            36.7           19.3              193.0
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream            55.8           19.8              207.0
# 340  Chinstrap      Dream            43.5           18.1              202.0
# 341  Chinstrap      Dream            49.6           18.2              193.0
# 342  Chinstrap      Dream            50.8           19.0              210.0
# 343  Chinstrap      Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# ...

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g  \
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000
#
#               year
# count   344.000000
# mean   2008.029070
# std       0.818356
# min    2007.000000
# 25%    2007.000000
# 50%    2008.000000
# 75%    2009.000000
# max    2009.000000

# %%
penguins.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                       75%     max
# bill_length_mm       48.5    59.6
# bill_depth_mm        18.7    21.5
# flipper_length_mm   213.0   231.0
# body_mass_g        4750.0  6300.0
# year               2009.0  2009.0

# %% [markdown]
# <h3> Checking for Null Values </h3>

# %%
penguins.isnull()
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0      False   False           False          False              False
# 1      False   False           False          False              False
# 2      False   False           False          False              False
# 3      False   False            True           True               True
# 4      False   False           False          False              False
# ..       ...     ...             ...            ...                ...
# 339    False   False           False          False              False
# 340    False   False           False          False              False
# 341    False   False           False          False              False
# 342    False   False           False          False              False
# 343    False   False           False          False              False
#
#      body_mass_g    sex   year
# 0          False  False  False
# 1          False  False  False
# ...

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# <h3> Filtering a column </h3>

# %%
penguins['species']
# Out:
# 0         Adelie
# 1         Adelie
# 2         Adelie
# 3         Adelie
# 4         Adelie
#          ...
# 339    Chinstrap
# 340    Chinstrap
# 341    Chinstrap
# 342    Chinstrap
# 343    Chinstrap
# Name: species, Length: 344, dtype: object

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguins['species'] == 'Chinstrap'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340     True
# 341     True
# 342     True
# 343     True
# Name: species, Length: 344, dtype: bool

# %%
penguins['species'] != 'Chinstrap'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: species, Length: 344, dtype: bool

# %%
penguins[penguins['species'] != 'Chinstrap']
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 271  Gentoo     Biscoe             NaN            NaN                NaN
# 272  Gentoo     Biscoe            46.8           14.3              215.0
# 273  Gentoo     Biscoe            50.4           15.7              222.0
# 274  Gentoo     Biscoe            45.2           14.8              212.0
# 275  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# 0         3750.0    male  2007
# ...

# %%
penguins['island'] == 'Torgersen'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 339    False
# 340    False
# 341    False
# 342    False
# 343    False
# Name: island, Length: 344, dtype: bool

# %%
chinstrap_df = penguins[penguins['species'] == 'Chinstrap']

# %%
chinstrap_df
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# 277       3900.0    male  2007
# ...

# %%
penguins ['body_mass_g']
# Out:
# 0      3750.0
# 1      3800.0
# 2      3250.0
# 3         NaN
# 4      3450.0
#         ...
# 339    4000.0
# 340    3400.0
# 341    3775.0
# 342    4100.0
# 343    3775.0
# Name: body_mass_g, Length: 344, dtype: float64

# %%
#(penguins['species'] == 'Chinstrap')
penguins ['body_mass_g'] >= 4000
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 339     True
# 340    False
# 341    False
# 342     True
# 343    False
# Name: body_mass_g, Length: 344, dtype: bool

# %%
penguins[(penguins['species'] == 'Chinstrap') & (penguins ['body_mass_g'] >= 4000)]
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 284  Chinstrap  Dream            46.0           18.9              195.0
# 289  Chinstrap  Dream            52.0           18.1              201.0
# 291  Chinstrap  Dream            50.5           19.6              201.0
# 295  Chinstrap  Dream            49.2           18.2              195.0
# 301  Chinstrap  Dream            52.0           19.0              197.0
# 305  Chinstrap  Dream            52.8           20.0              205.0
# 307  Chinstrap  Dream            54.2           20.8              201.0
# 309  Chinstrap  Dream            51.0           18.8              203.0
# 313  Chinstrap  Dream            52.0           20.7              210.0
# 315  Chinstrap  Dream            53.5           19.9              205.0
# 321  Chinstrap  Dream            50.8           18.5              201.0
# 323  Chinstrap  Dream            49.0           19.6              212.0
# ...

# %%
chinstrap_heavy = penguins[(penguins['species'] == 'Chinstrap') & (penguins ['body_mass_g'] >= 4000)]

# %%
chinstrap_df.info
# Out:
# <bound method DataFrame.info of        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 276  Chinstrap  Dream            46.5           17.9              192.0
# 277  Chinstrap  Dream            50.0           19.5              196.0
# 278  Chinstrap  Dream            51.3           19.2              193.0
# 279  Chinstrap  Dream            45.4           18.7              188.0
# 280  Chinstrap  Dream            52.7           19.8              197.0
# ..         ...    ...             ...            ...                ...
# 339  Chinstrap  Dream            55.8           19.8              207.0
# 340  Chinstrap  Dream            43.5           18.1              202.0
# 341  Chinstrap  Dream            49.6           18.2              193.0
# 342  Chinstrap  Dream            50.8           19.0              210.0
# 343  Chinstrap  Dream            50.2           18.7              198.0
#
#      body_mass_g     sex  year
# 276       3500.0  female  2007
# ...

# %% [markdown]
# <h2> FILLING UP NULL VALUES</h2>

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['bill_length_mm']
# Out:
# 0      39.1
# 1      39.5
# 2      40.3
# 3       NaN
# 4      36.7
#        ...
# 339    55.8
# 340    43.5
# 341    49.6
# 342    50.8
# 343    50.2
# Name: bill_length_mm, Length: 344, dtype: float64

# %%
penguins['bill_length_mm'].mean()
# Out:
# np.float64(43.9219298245614)

# %%
penguins['bill_length_mm'] = penguins['bill_length_mm'].fillna(penguins['bill_length_mm'].mean())

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['bill_length_mm'].mode()
# Out:
# 0    41.1
# Name: bill_length_mm, dtype: float64

# %%
penguins['sex'] = penguins['sex'].fillna(penguins['sex'].mode()[0])

# %%
penguins.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        2
# flipper_length_mm    2
# body_mass_g          2
# sex                  0
# year                 0
# dtype: int64

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     344 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                344 non-null    object
#  7   year               344 non-null    int64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 21.6+ KB

# %%
penguins['species'] = penguins['species'].astype('category')
penguins['year'] = penguins['year'].astype('category')

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    category
#  1   island             344 non-null    object
#  2   bill_length_mm     344 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                344 non-null    object
#  7   year               344 non-null    category
# dtypes: category(2), float64(4), object(2)
# memory usage: 17.2+ KB

# %%
penguins.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      344.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.443643       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.275000      15.600000         190.000000  3550.000000
# 50%         44.250000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %% [markdown]
# <h2>Exploratory Data Analytics</h2>

# %%
penguins['body_mass_g'].mean()
# Out:
# np.float64(4201.754385964912)

# %%
gentoo_df = penguins[penguins['species'] == 'Gentoo']

# %%
gentoo_df['body_mass_g'].mean()
# Out:
# np.float64(5076.016260162602)

# %%
Chinstrap_df = penguins[penguins['species'] == 'Chinstrap']

# %%
Chinstrap_df['body_mass_g'].mean()
# Out:
# np.float64(3733.0882352941176)

# %%
adelie_df = penguins[penguins['species'] == 'Adelie']

# %%
adelie_df['body_mass_g'].mean()
# Out:
# np.float64(3700.662251655629)

# %% [markdown]
# <h2>Insight No.1</h2>

# %% [markdown]
# <p>Gentoo has the heaviest average body mass</p>

# %% [markdown]
# <h1>How to create your own columns</h1>

# %%
penguins['study_year'] = 2025

# %%
penguins['bill_ratio'] = penguins['bill_length_mm'] / penguins['bill_depth_mm']

# %%
penguins['is_gentoo'] = penguins['species'] == 'Gentoo'

# %%
penguins['mass_category'] = penguins['body_mass_g'].apply(
    lambda x: 'Heavy' if x > 4500 else 'Light'
)

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    category
#  1   island             344 non-null    object
#  2   bill_length_mm     344 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                344 non-null    object
#  7   year               344 non-null    category
#  8   study_year         344 non-null    int64
#  9   bill_ratio         342 non-null    float64
#  10  is_gentoo          344 non-null    bool
#  11  mass_category      344 non-null    object
# dtypes: bool(1), category(2), float64(5), int64(1), object(3)
# memory usage: 25.6+ KB

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year', 'study_year',
#        'bill_ratio', 'is_gentoo', 'mass_category'],
#       dtype='object')

# %%
penguins['mass_kg'] = penguins['body_mass_g'] / 1000

# %%
columns_to_fill = ['bill_length_mm', 'bill_depth_mm', 'flipper_length_mm', 'body_mass_g']
for col in columns_to_fill:
    penguins[col] = penguins[col].fillna(penguins[col].mean())

# %%
penguins.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# study_year           0
# bill_ratio           2
# is_gentoo            0
# mass_category        0
# mass_kg              2
# dtype: int64

# %%
import numpy as np  # Make sure numpy is imported

penguins['mass_kg'] = np.round(penguins['body_mass_g'] / 2000, 1)

# %%
penguins
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       Adelie  Torgersen        39.10000       18.70000         181.000000
# 1       Adelie  Torgersen        39.50000       17.40000         186.000000
# 2       Adelie  Torgersen        40.30000       18.00000         195.000000
# 3       Adelie  Torgersen        43.92193       17.15117         200.915205
# 4       Adelie  Torgersen        36.70000       19.30000         193.000000
# ..         ...        ...             ...            ...                ...
# 339  Chinstrap      Dream        55.80000       19.80000         207.000000
# 340  Chinstrap      Dream        43.50000       18.10000         202.000000
# 341  Chinstrap      Dream        49.60000       18.20000         193.000000
# 342  Chinstrap      Dream        50.80000       19.00000         210.000000
# 343  Chinstrap      Dream        50.20000       18.70000         198.000000
#
# ...

# %%
penguins['mass_kg'].max()
# Out:
# np.float64(3.2)

# %%
penguins[penguins['mass_kg'] == 2.1]
# Out:
#        species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 3       Adelie  Torgersen        43.92193       17.15117         200.915205
# 9       Adelie  Torgersen        42.00000       20.20000         190.000000
# 19      Adelie  Torgersen        46.00000       21.50000         194.000000
# 35      Adelie      Dream        39.20000       21.10000         196.000000
# 49      Adelie      Dream        42.30000       21.20000         191.000000
# 73      Adelie  Torgersen        45.80000       18.90000         197.000000
# 75      Adelie  Torgersen        42.80000       18.50000         195.000000
# 83      Adelie  Torgersen        35.10000       19.40000         193.000000
# 103     Adelie     Biscoe        37.80000       20.00000         190.000000
# 113     Adelie     Biscoe        42.20000       19.50000         197.000000
# 139     Adelie      Dream        39.70000       17.90000         193.000000
# ...

# %%
penguins['mass_kg'].mean()
# Out:
# np.float64(2.101453488372093)

# %%
penguins[penguins['mass_kg'] >= 2.1]['island']
# Out:
# 3      Torgersen
# 7      Torgersen
# 9      Torgersen
# 14     Torgersen
# 17     Torgersen
#          ...
# 307        Dream
# 313        Dream
# 315        Dream
# 321        Dream
# 323        Dream
# Name: island, Length: 162, dtype: object

# %%
penguins[penguins['mass_kg'] >= 2.1]['species']
# Out:
# 3         Adelie
# 7         Adelie
# 9         Adelie
# 14        Adelie
# 17        Adelie
#          ...
# 307    Chinstrap
# 313    Chinstrap
# 315    Chinstrap
# 321    Chinstrap
# 323    Chinstrap
# Name: species, Length: 162, dtype: category
# Categories (3, object): ['Adelie', 'Chinstrap', 'Gentoo']

# %%
penguins.describe(include='all')
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count      344     344      344.000000     344.000000         344.000000
# unique       3       3             NaN            NaN                NaN
# top     Adelie  Biscoe             NaN            NaN                NaN
# freq       152     168             NaN            NaN                NaN
# mean       NaN     NaN       43.921930      17.151170         200.915205
# std        NaN     NaN        5.443643       1.969027          14.020657
# min        NaN     NaN       32.100000      13.100000         172.000000
# 25%        NaN     NaN       39.275000      15.600000         190.000000
# 50%        NaN     NaN       44.250000      17.300000         197.000000
# 75%        NaN     NaN       48.500000      18.700000         213.000000
# max        NaN     NaN       59.600000      21.500000         231.000000
#
#         body_mass_g   sex    year  study_year  bill_ratio is_gentoo  \
# ...

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguins['species'].unique()
# Out:
# ['Adelie', 'Gentoo', 'Chinstrap']
# Categories (3, object): ['Adelie', 'Chinstrap', 'Gentoo']

# %%
penguins.head(20)
# Out:
#    species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   Adelie  Torgersen        39.10000       18.70000         181.000000
# 1   Adelie  Torgersen        39.50000       17.40000         186.000000
# 2   Adelie  Torgersen        40.30000       18.00000         195.000000
# 3   Adelie  Torgersen        43.92193       17.15117         200.915205
# 4   Adelie  Torgersen        36.70000       19.30000         193.000000
# 5   Adelie  Torgersen        39.30000       20.60000         190.000000
# 6   Adelie  Torgersen        38.90000       17.80000         181.000000
# 7   Adelie  Torgersen        39.20000       19.60000         195.000000
# 8   Adelie  Torgersen        34.10000       18.10000         193.000000
# 9   Adelie  Torgersen        42.00000       20.20000         190.000000
# 10  Adelie  Torgersen        37.80000       17.10000         186.000000
# 11  Adelie  Torgersen        37.80000       17.30000         180.000000
# ...

# %%
penguins.tail(20)
# Out:
#        species island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 324  Chinstrap  Dream            51.5           18.7              187.0
# 325  Chinstrap  Dream            49.8           17.3              198.0
# 326  Chinstrap  Dream            48.1           16.4              199.0
# 327  Chinstrap  Dream            51.4           19.0              201.0
# 328  Chinstrap  Dream            45.7           17.3              193.0
# 329  Chinstrap  Dream            50.7           19.7              203.0
# 330  Chinstrap  Dream            42.5           17.3              187.0
# 331  Chinstrap  Dream            52.2           18.8              197.0
# 332  Chinstrap  Dream            45.2           16.6              191.0
# 333  Chinstrap  Dream            49.3           19.9              203.0
# 334  Chinstrap  Dream            50.2           18.8              202.0
# 335  Chinstrap  Dream            45.6           19.4              194.0
# ...

# %% [markdown]
# <h1>Data Aggregation</h1>

# %% [raw]
# ilan species ng penguins ang nakatira per island ?

# %%
species_island = penguins.groupby(['species','island','sex','year'], observed=True).size()

# %%
species_island
# Out:
# species    island     sex     year
# Adelie     Biscoe     female  2007     5
#                               2008     9
#                               2009     8
#                       male    2007     5
#                               2008     9
#                               2009     8
#            Dream      female  2007     9
#                               2008     8
#                               2009    10
#                       male    2007    11
#                               2008     8
#                               2009    10
#            Torgersen  female  2007     8
#                               2008     8
#                               2009     8
#                       male    2007    12
#                               2008     8
#                               2009     8
# Chinstrap  Dream      female  2007    13
#                               2008     9
#                               2009    12
#                       male    2007    13
# ...

# %%
penguins.dtypes
# Out:
# species              category
# island                 object
# bill_length_mm        float64
# bill_depth_mm         float64
# flipper_length_mm     float64
# body_mass_g           float64
# sex                    object
# year                 category
# study_year              int64
# bill_ratio            float64
# is_gentoo                bool
# mass_category          object
# mass_kg               float64
# dtype: object

# %% [raw]
# average weight of penguins per island and sex ?

# %%
avg_island_s = penguins.groupby(['species', 'island', 'sex'], observed=False)['body_mass_g'].mean()

# %%
avg_island_s = penguins.groupby(['species', 'island', 'sex'], observed=True)['body_mass_g'].mean()

# %% [markdown]
# <h1>CORRELATION ANALYSIS</h1>
# <hr>
# <h3>Testing Correlation using Person R</h3>
# <hr>
# <p><b>Person R<b> can test correlation between two Variables, given that both
# Variables are </p><strong>NUMBERICAL DATA</strong>

# %%
flipper_mass = penguins['body_mass_g'].corr(penguins['flipper_length_mm'])
print(flipper_mass)
correlation_matrix = penguins.corr(numeric_only=True)
print(correlation_matrix)
# Out:
# 0.8712017673060114
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
# study_year                    NaN            NaN                NaN
# bill_ratio               0.780396      -0.784191           0.805166
# is_gentoo                0.490869      -0.821550           0.865530
# mass_kg                  0.590236      -0.468188           0.869495
#
#                    body_mass_g  study_year  bill_ratio  is_gentoo   mass_kg
# bill_length_mm        0.595110         NaN    0.780396   0.490869  0.590236
# bill_depth_mm        -0.471916         NaN   -0.784191  -0.821550 -0.468188
# flipper_length_mm     0.871202         NaN    0.805166   0.865530  0.869495
# ...

# %%
penguins.dtypes
# Out:
# species              category
# island                 object
# bill_length_mm        float64
# bill_depth_mm         float64
# flipper_length_mm     float64
# body_mass_g           float64
# sex                    object
# year                 category
# study_year              int64
# bill_ratio            float64
# is_gentoo                bool
# mass_category          object
# mass_kg               float64
# dtype: object

# %%
flipper_mass
# Out:
# np.float64(0.8712017673060114)

# %%
from scipy.stats import f_oneway

# %%
penguins[penguins['sex'] == 'male']['body_mass_g']
# Out:
# 0      3750.000000
# 3      4201.754386
# 5      3650.000000
# 7      4675.000000
# 8      3475.000000
#           ...
# 334    3800.000000
# 336    3950.000000
# 339    4000.000000
# 341    3775.000000
# 342    4100.000000
# Name: body_mass_g, Length: 179, dtype: float64

# %%
penguins[penguins['sex'] == 'female']['body_mass_g']
# Out:
# 1      3800.0
# 2      3250.0
# 4      3450.0
# 6      3625.0
# 12     3200.0
#         ...
# 335    3525.0
# 337    3650.0
# 338    3650.0
# 340    3400.0
# 343    3775.0
# Name: body_mass_g, Length: 165, dtype: float64

# %%
stats, p_value = f_oneway(penguins[penguins['sex'] == 'male']['body_mass_g'] ,penguins[penguins['sex'] == 'male']['body_mass_g'])

# %%
correlation_matrix = penguins.corr(numeric_only=True)
print(correlation_matrix)
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
# study_year                    NaN            NaN                NaN
# bill_ratio               0.780396      -0.784191           0.805166
# is_gentoo                0.490869      -0.821550           0.865530
# mass_kg                  0.590236      -0.468188           0.869495
#
#                    body_mass_g  study_year  bill_ratio  is_gentoo   mass_kg
# bill_length_mm        0.595110         NaN    0.780396   0.490869  0.590236
# bill_depth_mm        -0.471916         NaN   -0.784191  -0.821550 -0.468188
# flipper_length_mm     0.871202         NaN    0.805166   0.865530  0.869495
# ...

# %% [markdown]
# <h1>Testing Correlation Between Numberical and Categorical Data</h1>

# %% [markdown]
# <h4>Body mass v sex</h4>

# %%
#import scipy.stats
from scipy.stats import f_oneway

# %%
#filter data
penguins[penguins['sex'] == 'male']['body_mass_g']
# Out:
# 0      3750.000000
# 3      4201.754386
# 5      3650.000000
# 7      4675.000000
# 8      3475.000000
#           ...
# 334    3800.000000
# 336    3950.000000
# 339    4000.000000
# 341    3775.000000
# 342    4100.000000
# Name: body_mass_g, Length: 179, dtype: float64

# %%
import scipy.stats as stats

# Does body mass vary across species?
anova_result = stats.f_oneway(
    penguins[penguins['species'] == 'Adelie']['body_mass_g'],
    penguins[penguins['species'] == 'Gentoo']['body_mass_g'],
    penguins[penguins['species'] == 'Chinstrap']['body_mass_g']
)
print(anova_result)
# Out:
# F_onewayResult(statistic=np.float64(338.5729100782222), pvalue=np.float64(1.0069770504490335e-81))

# %%
penguins[penguins['sex'] == 'female']['body_mass_g']
# Out:
# 1      3800.0
# 2      3250.0
# 4      3450.0
# 6      3625.0
# 12     3200.0
#         ...
# 335    3525.0
# 337    3650.0
# 338    3650.0
# 340    3400.0
# 343    3775.0
# Name: body_mass_g, Length: 165, dtype: float64

# %%
print(penguins['sex'].unique())
print(penguins['sex'].value_counts(dropna=False))
print(penguins['body_mass_g'].isnull().sum())
# Out:
# ['male' 'female']
# sex
# male      179
# female    165
# Name: count, dtype: int64
# 0

# %%
print(f"Male sample size: {len(male_mass)}")
print(f"Female sample size: {len(female_mass)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[79], line 1
# ----> 1 print(f"Male sample size: {len(male_mass)}")
#       2 print(f"Female sample size: {len(female_mass)}")
#
# NameError: name 'male_mass' is not defined

# %%
print(penguins[['body_mass_g', 'sex']].info())
print(penguins['sex'].value_counts(dropna=False))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   body_mass_g  344 non-null    float64
#  1   sex          344 non-null    object
# dtypes: float64(1), object(1)
# memory usage: 5.5+ KB
# None
# sex
# male      179
# female    165
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='sex', y='body_mass_g', data=penguins)
plt.title('Body Mass Distribution by Sex')
plt.show()

# %%
from scipy.stats import ttest_ind

# Drop missing values first
clean_data = penguins.dropna(subset=['body_mass_g', 'sex'])

male_mass = clean_data[clean_data['sex'] == 'Male']['body_mass_g']
female_mass = clean_data[clean_data['sex'] == 'Female']['body_mass_g']

t_stat, p_value = ttest_ind(male_mass, female_mass)

print(penguins['sex'].unique())
print(penguins['sex'].value_counts(dropna=False))
# Out:
# ['male' 'female']
# sex
# male      179
# female    165
# Name: count, dtype: int64
# C:\Users\LAB4-StudentPC01\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\scipy\_lib\deprecation.py:234: SmallSampleWarning: One or more sample arguments is too small; all returned values will be NaN. See documentation for sample size requirements.
#   return f(*args, **kwargs)

# %%
clean_data = penguins.dropna(subset=['sex', 'body_mass_g'])
clean_data['sex'] = clean_data['sex'].str.lower()

male_mass = clean_data[clean_data['sex'] == 'male']['body_mass_g']
female_mass = clean_data[clean_data['sex'] == 'female']['body_mass_g']

# %%
p_value
# Out:
# np.float64(1.0)
